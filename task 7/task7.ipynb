# %%
import pandas as pd
authors=pd.read_csv('sampling.csv')
authors.head()
# Out:
#    Unnamed: 0                                           Citation  \
# 0           0                         Cytokine 33 (2006) 138e144
# 1           1  PLOS Pathogens, January 2014 | Volume 10 | Iss...
# 2           2  PLOS ONE, August 2013 | Volume 8 | Issue 8 | e...
# 3           3        Cancer Cell 26, 754Ä769, November 10, 2014
# 4           4                    Infect. Immun. 2012, 80(8):2689
#
#                             DOI  Year  \
# 0           10.1155/2014/989340  2007
# 1           10.1155/2013/308130  2009
# 2         10.1128/mBio.00275-11  2012
# 3                 PMID: 9620397  2014
# 4  10.1371/journal.ppat.1003896  2013
#
#                                             FINDINGS  \
# 0  Duplicated or mirrored blot panels, or lanes w...
# 1              Two sets of rotated microscopy images
# 2  two sets of duplicated facs panels but differe...
# 3            Reused lanes, possibly duplicated lanes
# 4                              Duplicated blot panel
#
# ...

# %%
fake=pd.read_csv('new_combine.csv')
fake.head()
# Out:
#    Unnamed: 0                                             author  \
# 0           0  Abagael Abagail, Abbe Abbey, Abbi Abbie, Abby ...
# 1           1  Ada Adah, Adaline Adara, Addie Addis, Adel Ade...
# 2           2  Adelind Adeline, Adella Adelle, Adena Adey, Ad...
# 3           3  Adorne Adrea, Adria Adriaens, Adrian Adriana, ...
# 4           4  Aeriel Aeriela, Aeriell Ag, Agace Agata, Agath...
#
#                                                title  \
# 0                                  Pulser vs. Vulcan
# 1  The caspase-1-active caspase-2 is a self-incom...
# 2  cmc_kills_bp(9) -cKlaxg2 -Dpk_Kills__ p+__c__k...
# 3  I like the 3.5-in. R9 270 a lot, but I'm not a...
# 4  In their analysis, they found that vegetarians...
#
#                                                 text
# 0  A). Blood samples were collected by centrifuga...
# 1  I was asked to give my brief opinion on the su...
# 2  .\n\nProbimin and psilocybin: a cross-species ...
# ...

# %%
# author
author=list(fake['author'])
author=random.choices(author,k=500)
# author

# %%
# text
text=list(fake['text'])
text=random.choices(text,k=500)
# text

# %%
# title
title=list(fake['title'])
title=random.choices(title,k=500)
# title

# %%
# Citation
import random
Citation=list(authors['Citation'])
Citation=random.choices(Citation,k=500)
# Citation

# %%
# DOI
DOI=list(authors['DOI'])
DOI=random.choices(DOI,k=500)
# DOI

# %%
# Year
Year=list(authors['Year'])
Year=random.choices(Year,k=500)
# Year

# %%
# FINDINGS
FINDINGS=list(authors['FINDINGS'])
FINDINGS=random.choices(FINDINGS,k=500)
# FINDINGS

# %%
#institution names
aff=list(authors['affiliation'])
affiliation=random.choices(aff,k=500)
# affiliation

# %%
# lab_size
lab_size=list(authors['lab_size'])
lab_size=random.choices(lab_size,k=500)
# lab_size

# %%
# Highest_degree
Highest_degree=list(authors['Highest_degree'])
Highest_degree=random.choices(Highest_degree,k=500)
# Highest_degree

# %%
# Degree_area
Degree_area=list(authors['Degree_area'])
Degree_area=random.choices(Degree_area,k=500)
# Degree_area

# %%
# Publication Rate
Publication_Rate=list(authors['Publication_Rate'])
Publication_Rate=random.choices(Publication_Rate,k=500)
# Publication_Rate

# %%
# Other Journals Published In
Other_Journals=list(authors['Other Journals Published In'])
Other_Journals=random.choices(Other_Journals,k=500)
# Other_Journals

# %%
# duration of Career(Years)
duration=list(authors['duration of Career(Years)'])
duration=random.choices(duration,k=500)
# duration

# %%
data={
    'Author':author,
    'Title':title,
    'Text':text,
    'Citation':Citation,
    'DOI':DOI,
    'Year':Year,
    'FINDINGS':FINDINGS,
    'affiliation':affiliation,
    'lab_size':lab_size,
    'Highest_degree':Highest_degree,
    'Degree_area':Degree_area,
    'Publication_Rate':Publication_Rate,
    'Other Journals Published In':Other_Journals,
    'duration of Career(Years)':duration   
}
df=pd.DataFrame(data)
df
# Out:
#                                                 Author  \
# 0    Dedie Dedra, Dee Dee Dee, Deeann Deeanne, Deed...
# 1    Domenic Domenico, Dominic Dominick, Dominique ...
# 2    Rica Ricca, Rici Ricki, Rickie Ricky, Riki Rik...
# 3    Cyndi Cyndy, Cynthea Cynthia, Cynthie Cynthy, ...
# 4    Oralia Oralie, Oralla Oralle, Orel Orelee, Ore...
# ..                                                 ...
# 495  Robyn Roch, Rochell Rochella, Rochelle Rochett...
# 496  Estella Estelle, Ester Esther, Estrella Estrel...
# 497  Eleanor Eleanora, Eleanore Electra, Elena Elen...
# 498  Bjorn Bjorne, Blaine Blair, Blake Blare, Blayn...
# 499  Rae Raf, Rafa Rafaela, Rafaelia Rafaelita, Rag...
#
#                                                  Title  \
# 0    "I am ready to go and play in the Premier Leag...
# 1    The Koryo Robot will be able to detect and fie...
# 2                   As such, the newly formed Captain.
# 3    "I think, as a general rule, when you look at ...
# ...

# %%
df.to_csv('feature_added.csv')

# %%
pd_all = pd.read_csv("feature_added.csv", sep=',', encoding='utf-8')
pd_all.to_csv("feature_added.tsv", index=False, sep='\t', encoding='utf-8')
